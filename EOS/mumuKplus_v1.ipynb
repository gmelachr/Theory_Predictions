# %%
import eos

# %%
eos.Parameters()['decay-constant::B_u']
# Out:
#     <table>
#         <tr>
#             <th>$$f_{B^-}$$</th>
#             <td>(eos.Parameter)</td>
#         </tr>
#         <tr>
#             <th>current value</th>
#             <td><tt>0.1894</tt></td>
#         </tr>
#         <tr>
#             <th>default value</th>
#             <td><tt>0.1894</tt></td>
#         </tr>
#     </table>

# %%
EOS_BASE_DIRECTORY='./predictions-base'

# %%
eos.tasks.sample_prior('./predictions.yaml','SM',base_directory=EOS_BASE_DIRECTORY,N=2000,seed=42)
# Out:
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('data/SM/samples',))

# %%
output = eos.data.ImportanceSamples(EOS_BASE_DIRECTORY + '/data/SM/samples')
display(output.samples.shape)
# Out:
# (2000, 1)

# %%
eos.tasks.predict_observables('./predictions.yaml','SM','Bplus-to-Kplus-mu-mu',base_directory=EOS_BASE_DIRECTORY)
# Out:
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('data/SM/pred-Bplus-to-K…

# %%
# !tree ./predictions-base
# Out:
# ./predictions-base
# └── data
#     └── SM
#         ├── pred-Bplus-to-Kplus-mu-mu
#         │   ├── description.yaml
#         │   ├── log
#         │   ├── samples.npy
#         │   └── weights.npy
#         └── samples
#             ├── description.yaml
#             ├── log
#             ├── samples.npy
#             └── weights.npy
#
# 4 directories, 8 files

# %%
import numpy as np
prediction = eos.data.Prediction(EOS_BASE_DIRECTORY + '/data/SM/pred-Bplus-to-Kplus-mu-mu')
avg = np.average(prediction.samples[:, 0], weights=prediction.weights, axis=0)
std = np.sqrt(np.average((prediction.samples[:, 0] - avg)**2, weights=prediction.weights, axis=0))
print(f'BR(B_u->KMuMu) = {100 * avg:.9f} +/- {100 * std:.9f} %')
# Out:
# BR(B_u->KMuMu) = 0.000003196 +/- 0.000000001 %

# %%
eos.tasks.sample_nested('predictions.yaml', 'FF-LQCD-SSE', base_directory=EOS_BASE_DIRECTORY, nlive=250, dlogz=0.5, seed=42)
# Out:
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('data/FF-LQCD-SSE/nested…

# %%
# !tree -L 2 ./predictions-base
# Out:
# ./predictions-base
# └── data
#     ├── FF-LQCD-SSE
#     └── SM
#
# 3 directories, 0 files

# %%
eos.tasks.predict_observables('predictions.yaml', 'FF-LQCD-SSE', 'B-to-K-mu-mu-lowq2',  base_directory=EOS_BASE_DIRECTORY)
# Out:
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('data/FF-LQCD-SSE/pred-B…

# %%
figure_args = """
plot:
  xaxis: { label: '$q^2$', unit: '$\\textnormal{GeV}^2$', range: [0.0, 8] }
  yaxis: { label: '$d\\mathcal{B}/dq^2$',                 range: [0.0,  5e-8] }
  legend: { position: 'upper center' }
  items:
    - { type: 'uncertainty', label: '$\\ell=\\mu$',
        variable: 'q2', range: [0.00, 8.0],
        datafile: './predictions-base/data/FF-LQCD-SSE/pred-B-to-K-mu-mu-lowq2'
      }
"""
figure = eos.figure.FigureFactory.from_yaml(figure_args)
figure.draw()

# %%
eos.tasks.predict_observables('predictions.yaml', 'FF-LQCD-SSE', 'B-to-K-mu-mu-lowq2-binned',  base_directory=EOS_BASE_DIRECTORY)
# Out:
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('data/FF-LQCD-SSE/pred-B…

# %%
eos.tasks.predict_observables('predictions.yaml', 'FF-LQCD-SSE', 'B-to-K-mu-mu-highq2-binned',  base_directory=EOS_BASE_DIRECTORY)
# Out:
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('data/FF-LQCD-SSE/pred-B…

# %%
figure_args = """
plot:
  xaxis: { label: '$q^2$', unit: '$\\textnormal{GeV}^2$', range: [0.0, 23] }
  yaxis: { label: '$d\\mathcal{B}/dq^2$',                 range: [0.0,  5e-8] }
  legend: { position: 'upper center' }
  items:
    - { type: 'uncertainty-binned', label: '$GvDV2020$',
        variable: 'q2', range: [0.00, 23.0],
        datafile: './predictions-base/data/FF-LQCD-SSE/pred-B-to-K-mu-mu-lowq2-binned'
      }
    - { type: 'uncertainty-binned', label: '$GP2004$',
        variable: 'q2', range: [0.00, 23.0],
        datafile: './predictions-base/data/FF-LQCD-SSE/pred-B-to-K-mu-mu-highq2-binned'
      }      
"""
figure = eos.figure.FigureFactory.from_yaml(figure_args)
figure.draw()

import matplotlib.pyplot as plt
fig = plt.gcf()
fig.savefig('Bplus_to_Kplus_mumu.png', bbox_inches='tight')

# %%
import os

print(os.listdir('./predictions-base/data/FF-LQCD-SSE/pred-B-to-K-mu-mu-lowq2-binned'))
# Out:
# ['weights.npy', 'description.yaml', 'samples.npy', 'log']

# %%
print(os.listdir('./predictions-base/data/FF-LQCD-SSE/pred-B-to-K-mu-mu-highq2-binned'))
# Out:
# ['weights.npy', 'description.yaml', 'samples.npy', 'log']

# %%
import numpy as np
import pandas as pd
import yaml

def prediction_table(path, bins):
    samples = np.load(f"{path}/samples.npy")   # shape: (N samples, N observables)
    weights = np.load(f"{path}/weights.npy")

    # normalize weights
    weights = weights / np.sum(weights)

    rows = []
    for i, (q2_min, q2_max) in enumerate(bins):
        x = samples[:, i]

        central = np.average(x, weights=weights)
        variance = np.average((x - central)**2, weights=weights)
        sigma = np.sqrt(variance)

        rows.append({
            "q2_min": q2_min,
            "q2_max": q2_max,
            "q2_center": 0.5 * (q2_min + q2_max),
            "central": central,
            "sigma": sigma,
            "lower": central - sigma,
            "upper": central + sigma,
        })

    return pd.DataFrame(rows)

low_bins = [
    (1.1, 2.0),
    (2.0, 3.0),
    (3.0, 4.0),
    (4.0, 5.0),
    (5.0, 6.0),
    (6.0, 7.0),
    (7.0, 8.0),
]

high_bins = [
    (15.0, 16.0),
    (16.0, 17.0),
    (17.0, 18.0),
    (18.0, 19.0),
    (19.0, 20.0),
    (20.0, 21.0),
    (21.0, 22.0),
]

low_df = prediction_table(
    "./predictions-base/data/FF-LQCD-SSE/pred-B-to-K-mu-mu-lowq2-binned",
    low_bins
)

high_df = prediction_table(
    "./predictions-base/data/FF-LQCD-SSE/pred-B-to-K-mu-mu-highq2-binned",
    high_bins
)

df = pd.concat([low_df, high_df], ignore_index=True)
df

df.to_csv("Bplus_to_Kplus_mumu_EOS_predictions.csv", index=False)
